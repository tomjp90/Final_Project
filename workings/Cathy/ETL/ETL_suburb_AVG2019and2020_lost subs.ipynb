# %% [markdown]
# # Extract - Melbourne House Data

# %%
# Imports
import pandas as pd
import numpy as np

# %%
# Reading in dataframe from CSV
df = pd.read_csv("Resources/Melbourne_housing_FULL.csv")
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
#    YearBuilt         CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN  Yarra City Council  -37.8014    144.9958  Northern Metropolitan
# 1        NaN  Yarra City Council  -37.7996    144.9984  Northern Metropolitan
# 2     1900.0  Yarra City Council  -37.8079    144.9934  Northern Metropolitan
# 3        NaN  Yarra City Council  -37.8114    145.0116  Northern Metropolitan
# 4     1900.0  Yarra City Council  -37.8093    144.9944  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %% [markdown]
# # EDA AND TRANSFORM - Melbourne House Data

# %%
full_len = len(df)
full_len
# Out:
# 34857

# %%
# Splitting the date
df[['Day', 'Month', 'Year']] = df["Date"].str.split("/", expand=True,)
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  BuildingArea  YearBuilt  \
# 0  3/09/2016       2.5    3067.0  ...           NaN        NaN
# 1  3/12/2016       2.5    3067.0  ...           NaN        NaN
# 2  4/02/2016       2.5    3067.0  ...          79.0     1900.0
# 3  4/02/2016       2.5    3067.0  ...           NaN        NaN
# 4  4/03/2017       2.5    3067.0  ...         150.0     1900.0
#
#           CouncilArea  Lattitude  Longtitude             Regionname  \
# 0  Yarra City Council   -37.8014    144.9958  Northern Metropolitan
# 1  Yarra City Council   -37.7996    144.9984  Northern Metropolitan
# 2  Yarra City Council   -37.8079    144.9934  Northern Metropolitan
# 3  Yarra City Council   -37.8114    145.0116  Northern Metropolitan
# 4  Yarra City Council   -37.8093    144.9944  Northern Metropolitan
#
#   Propertycount  Day  Month  Year
# 0        4019.0    3     09  2016
# 1        4019.0    3     12  2016
# 2        4019.0    4     02  2016
# 3        4019.0    4     02  2016
# 4        4019.0    4     03  2017
#
# [5 rows x 24 columns]

# %%
# List of columns
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount', 'Day', 'Month', 'Year'],
#       dtype='object')

# %%
# Reducing to columns of interest
# 'Landsize'
df = df.loc[:,['Suburb', 'Rooms', 'Type', 'Price', 'Bathroom', 'Car', 'Month', 'Year']]
df.head()
# Out:
#        Suburb  Rooms Type      Price  Bathroom  Car Month  Year
# 0  Abbotsford      2    h        NaN       1.0  1.0    09  2016
# 1  Abbotsford      2    h  1480000.0       1.0  1.0    12  2016
# 2  Abbotsford      2    h  1035000.0       1.0  0.0    02  2016
# 3  Abbotsford      3    u        NaN       2.0  1.0    02  2016
# 4  Abbotsford      3    h  1465000.0       2.0  0.0    03  2017

# %%
# Changing column headers to lower case
df.columns = df.columns.str.lower()
df.head()
# Out:
#        suburb  rooms type      price  bathroom  car month  year
# 0  Abbotsford      2    h        NaN       1.0  1.0    09  2016
# 1  Abbotsford      2    h  1480000.0       1.0  1.0    12  2016
# 2  Abbotsford      2    h  1035000.0       1.0  0.0    02  2016
# 3  Abbotsford      3    u        NaN       2.0  1.0    02  2016
# 4  Abbotsford      3    h  1465000.0       2.0  0.0    03  2017

# %%
# Investigating columns with null values
df.isnull().sum()
# Out:
# suburb         0
# rooms          0
# type           0
# price       7610
# bathroom    8226
# car         8728
# month          0
# year           0
# dtype: int64

# %%
# Dropping these null values
house_df = df.dropna() 
house_df.head()
# Out:
#        suburb  rooms type      price  bathroom  car month  year
# 1  Abbotsford      2    h  1480000.0       1.0  1.0    12  2016
# 2  Abbotsford      2    h  1035000.0       1.0  0.0    02  2016
# 4  Abbotsford      3    h  1465000.0       2.0  0.0    03  2017
# 5  Abbotsford      3    h   850000.0       2.0  1.0    03  2017
# 6  Abbotsford      4    h  1600000.0       1.0  2.0    06  2016

# %%
# Checking the length and that removal of na has worked
final_len = len(house_df)
print(final_len)
print(house_df.isnull().sum())
# Out:
# 20423
# suburb      0
# rooms       0
# type        0
# price       0
# bathroom    0
# car         0
# month       0
# year        0
# dtype: int64

# %%
difference = full_len - final_len
percent = (difference/full_len)*100
(f"The dataframe has been reduced from {full_len} rows to {final_len} rows, by {round(percent,2)} percent")
# Out:
# 'The dataframe has been reduced from 34857 rows to 20423 rows, by 41.41 percent'

# %%
# Investigating different types of houses
house_df['type'].unique()
# Out:
# array(['h', 'u', 't'], dtype=object)

# %% [markdown]
# # Extract - VIC Crime Data

# %%
crime_vic_df = pd.read_csv("Resources/Data_Tables_LGA_Criminal_Incidents_Year_Ending_September_2020/Table 03-Table 1.csv")
crime_vic_df.head()
# Out:
#    Year Year ending Local Government Area  Postcode Suburb/Town Name  \
# 0  2020   September                Alpine      3691         Dederang
# 1  2020   September                Alpine      3691       Glen Creek
# 2  2020   September                Alpine      3691       Glen Creek
# 3  2020   September                Alpine      3691       Gundowring
# 4  2020   September                Alpine      3691       Gundowring
#
#                     Offence Division          Offence Subdivision  \
# 0  B Property and deception offences                    B40 Theft
# 1                    C Drug offences  C30 Drug use and possession
# 2                   F Other offences   F90 Miscellaneous offences
# 3  B Property and deception offences                    B40 Theft
# 4      E Justice procedures offences       E10 Justice procedures
#
#                Offence Subgroup Incidents Recorded
# 0       B41 Motor vehicle theft                  1
# 1           C32 Drug possession                  1
# 2        F93 Cruelty to animals                  1
# 3               B49 Other theft                  1
# 4  E13 Resist or hinder officer                  1

# %% [markdown]
# # EDA AND TRANSFORM - VIC Crime Data

# %%
# Investigating columns
crime_vic_df.columns
# Out:
# Index(['Year', 'Year ending', 'Local Government Area', 'Postcode',
#        'Suburb/Town Name', 'Offence Division', 'Offence Subdivision',
#        'Offence Subgroup', 'Incidents Recorded'],
#       dtype='object')

# %%
# This data is from 2020 and 2019 only
crime_vic_df['Year'].unique()
# Out:
# array([2020, 2019])

# %%
# Selecting columns of interest
crime_vic_df = crime_vic_df.loc[:,['Suburb/Town Name', 'Year', 'Incidents Recorded']]
crime_vic_df.head()
# Out:
#   Suburb/Town Name  Year Incidents Recorded
# 0         Dederang  2020                  1
# 1       Glen Creek  2020                  1
# 2       Glen Creek  2020                  1
# 3       Gundowring  2020                  1
# 4       Gundowring  2020                  1

# %%
# Renaming columns
crime_vic_df.columns = 'suburb', 'year', 'incidents_recorded'
crime_vic_df.head()
# Out:
#        suburb  year incidents_recorded
# 0    Dederang  2020                  1
# 1  Glen Creek  2020                  1
# 2  Glen Creek  2020                  1
# 3  Gundowring  2020                  1
# 4  Gundowring  2020                  1

# %%
# Seperating 2019 incidents from 2020 
crime_2019_df = crime_vic_df.loc[(crime_vic_df["year"] == 2019), :]
crime_2019_df.head()
# Out:
#          suburb  year incidents_recorded
# 34653  Dederang  2019                  1
# 34654  Dederang  2019                  1
# 34655  Dederang  2019                  1
# 34656  Dederang  2019                  1
# 34657  Dederang  2019                  1

# %%
# Changing col names
crime_2019_df = crime_2019_df.rename(columns = {"incidents_recorded" : "2019_incidents"})
crime_2019_df.head()
# Out:
#          suburb  year 2019_incidents
# 34653  Dederang  2019              1
# 34654  Dederang  2019              1
# 34655  Dederang  2019              1
# 34656  Dederang  2019              1
# 34657  Dederang  2019              1

# %%
# Dropping year column
crime_2019_df = crime_2019_df[["suburb", "2019_incidents"]]
crime_2019_df.head()
# Out:
#          suburb 2019_incidents
# 34653  Dederang              1
# 34654  Dederang              1
# 34655  Dederang              1
# 34656  Dederang              1
# 34657  Dederang              1

# %%
crime_2019_df.dtypes
# Out:
# suburb            object
# 2019_incidents    object
# dtype: object

# %%
# Removing , from numbers 
crime_2019_df['2019_incidents'] = crime_2019_df['2019_incidents'].str.replace(',', '')
# Converting from object to string to int
crime_2019_df['2019_incidents'] = crime_2019_df['2019_incidents'].astype(str).astype(int)

# %%
crime_2019_df.dtypes
# Out:
# suburb            object
# 2019_incidents     int64
# dtype: object

# %%
total_2019 = crime_2019_df.groupby("suburb")["2019_incidents"].sum()
total_2019_df = pd.DataFrame({
    "total_2019_inc" : total_2019
})
total_2019_df.head()
# Out:
#                total_2019_inc
# suburb
# Abbeyard                    1
# Aberfeldie                109
# Acheron                     4
# Adams Estate                2
# Adelaide Lead               3

# %%
# Seperating 2020 incidents from 2019 
crime_2020_df = crime_vic_df.loc[(crime_vic_df["year"] == 2020), :]
crime_2020_df.head()
# Out:
#        suburb  year incidents_recorded
# 0    Dederang  2020                  1
# 1  Glen Creek  2020                  1
# 2  Glen Creek  2020                  1
# 3  Gundowring  2020                  1
# 4  Gundowring  2020                  1

# %%
# Changing col names
crime_2020_df = crime_2020_df.rename(columns = {"incidents_recorded" : "2020_incidents"})
crime_2020_df.head()
# Out:
#        suburb  year 2020_incidents
# 0    Dederang  2020              1
# 1  Glen Creek  2020              1
# 2  Glen Creek  2020              1
# 3  Gundowring  2020              1
# 4  Gundowring  2020              1

# %%
# Dropping year column
crime_2020_df = crime_2020_df[["suburb", "2020_incidents"]]
crime_2020_df.head()
# Out:
#        suburb 2020_incidents
# 0    Dederang              1
# 1  Glen Creek              1
# 2  Glen Creek              1
# 3  Gundowring              1
# 4  Gundowring              1

# %%
crime_2020_df.dtypes
# Out:
# suburb            object
# 2020_incidents    object
# dtype: object

# %%
# Removing , from numbers 
crime_2020_df['2020_incidents'] = crime_2020_df['2020_incidents'].str.replace(',', '')
# Converting from object to string to int
crime_2020_df['2020_incidents'] = crime_2020_df['2020_incidents'].astype(str).astype(int)

# %%
crime_2020_df.dtypes
# Out:
# suburb            object
# 2020_incidents     int64
# dtype: object

# %%
total_2020 = crime_2020_df.groupby("suburb")["2020_incidents"].sum()
total_2020_df = pd.DataFrame({
    "total_2020_inc" : total_2020
})
total_2020_df.head()
# Out:
#               total_2020_inc
# suburb
# Abbotsford              1286
# Aberfeldie               120
# Acheron                    6
# Ada                        2
# Adams Estate              13

# %%
print(len(total_2020_df))
print(len(total_2019_df))
# Out:
# 2356
# 2219

# %%
# Merging 2019 and 2020 incidents together
crime_df = pd.merge(total_2020_df, total_2019_df, how = 'inner', on='suburb')
crime_df
# Out:
#                total_2020_inc  total_2019_inc
# suburb
# Aberfeldie                120             109
# Acheron                     6               4
# Adams Estate               13               2
# Adelaide Lead               2               3
# Aireys Inlet               30              16
# ...                       ...             ...
# Youanmite                   1               2
# Youarang                    2               1
# Yulecart                    1               3
# Yuroke                     16              17
# Zeerust                     7               1
#
# [1994 rows x 2 columns]

# %%
# Checking for null values 
crime_df.isnull().sum()
# Out:
# total_2020_inc    0
# total_2019_inc    0
# dtype: int64

# %%
# # Groupby of suburbs - summing incidents_recorded as they are all different types of crime?
# # IS THIS RIGHT ... FROM 2 DIFF YEARS SO SHOULD MAYBE SUM SEPERATELY AND THEN AVERAGE ON GROUPBY 
# total_incidents = crime_vic_df.groupby("suburb")["incidents_recorded"].sum()
# crime_df = pd.DataFrame({
#     "average_incidents" : avg_incidents
# })
# crime_df.head()

# %% [markdown]
# # Transform - merging house and crime data

# %%
# Merging two dataframes on suburb
combined_df = pd.merge(house_df, crime_df, how = 'inner', on='suburb')
combined_df
# Out:
#                 suburb  rooms type     price  bathroom  car month  year  \
# 0         Airport West      3    t  840000.0       2.0  1.0    09  2016
# 1         Airport West      3    h  730000.0       2.0  1.0    12  2016
# 2         Airport West      3    h  770000.0       2.0  1.0    03  2017
# 3         Airport West      2    h  603000.0       1.0  1.0    03  2017
# 4         Airport West      3    t  700000.0       2.0  2.0    03  2017
# ...                ...    ...  ...       ...       ...  ...   ...   ...
# 18613  Cranbourne West      3    h  530000.0       1.0  3.0    02  2018
# 18614      Wattle Glen      4    h  835000.0       2.0  2.0    01  2018
# 18615      Clyde North      3    h  575000.0       2.0  2.0    02  2018
# 18616      Lysterfield      3    h  730000.0       1.0  2.0    03  2018
# 18617         Kalkallo      3    h  615000.0       1.0  1.0    03  2018
#
#        total_2020_inc  total_2019_inc
# 0                 694             770
# 1                 694             770
# 2                 694             770
# 3                 694             770
# 4                 694             770
# ...               ...             ...
# 18613             940             806
# 18614              31              32
# 18615             911             705
# 18616             257             167
# 18617             327             164
#
# [18618 rows x 10 columns]

# %%
# Double checking for null values
combined_df.isnull().sum()
# Out:
# suburb            0
# rooms             0
# type              0
# price             0
# bathroom          0
# car               0
# month             0
# year              0
# total_2020_inc    0
# total_2019_inc    0
# dtype: int64

# %%
combined_len = len(combined_df)
print(f"Combined df length: {combined_len}")
print(f"We have lost {final_len - combined_len} rows of housing data when merging the 2 dataframes")
# Out:
# Combined df length: 18618
# We have lost 1805 rows of housing data when merging the 2 dataframes

# %%
# Number of suburbs in housing dataframe
house_subs = house_df['suburb'].nunique()
# Number of suburbs in combined dataframe
combined_subs = combined_df['suburb'].nunique()
print(f"Number of suburbs in combined df: {combined_subs}")
print(f'We have lost a total of {house_subs - combined_subs} suburbs from merging housing data with crime data.')
# Out:
# Number of suburbs in combined df: 299
# We have lost a total of 39 suburbs from merging housing data with crime data.

# %% [markdown]
# # LOAD / EXPORT TO CSV

# %%
# # Export final df to csv to create machine learning model
# combined_df.to_csv("Output/house_crime.csv")
