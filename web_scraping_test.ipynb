# %%
# import dependencies
from bs4 import BeautifulSoup as bs
import requests
import os
import pandas as pd
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
import time
from selenium import webdriver

# %%
def initialise_browser():
    executable_path = {'executable_path': ChromeDriverManager().install()}
    return Browser("chrome", **executable_path, headless=False)

# %%
url = "https://www.domain.com.au/970-drummond-street-carlton-north-vic-3054-2016951081"

# %%
import requests
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
html_content = requests.get(url, headers=headers)

# %%
html = html_content.text

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options



options = Options()
options.headless = True
options.add_argument("--window-size=1920,1200")
DRIVER_PATH = 'chromedriver'
driver = webdriver.Chrome(options=options, executable_path=DRIVER_PATH)
driver.get(url)
# print(driver.page_source)
html = driver.page_source 
html
driver.quit()

html
# Out:
# '<html lang="en-AU" data-version="8.15.239" data-build-git-hash="a926c9564214b38755c8b0ae458366efcd6a3bfb" data-build-time="Fri May 21 2021 10:26:01 GMT+1000 (Australian Eastern Standard Time)" data-build-id="master-3493"><head><link rel="dns-prefetch" href="//ads.rubiconproject.com"><link rel="dns-prefetch" href="//fastlane.rubiconproject.com"><meta charset="utf-8"><meta http-equiv="content-language" content="en-au"><meta name="format-detection" content="telephone=no"><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta name="viewport" content="width=device-width, initial-scale=1"><link rel="dns-prefetch" href="//static.domain.com.au"><link rel="dns-prefetch" href="//rimh2.domainstatic.com.au"><meta name="apple-mobile-web-app-capable" content="yes"><meta name="theme-color" content="#0ea800"><link rel="apple-touch-icon-precomposed" href="https://static.domain.com.au/domain/54.png"><link rel="apple-touch-icon-precomposed" href="https://static.domain.com.au/domain/72.png"><link rel="apple-touch-icon-precomposed" href="https://static.domain.com.au/domain/114.png"><link rel="apple-touch-icon-precomposed" href="https://static.domain.com.au/domain/144.png"><link rel="shortcut icon" href="https://static.domain.com.au/domain/favicon.ico"><link rel="preload" href="https://static.domain.com.au/content/fe-static/@domain-group/fe-brary/static/fonts/bolton/F37Bolton-Regular.woff2" as="font" type="font/woff2" crossorigin="true"><link rel="preload" href="https://static.domain.com.au/content/fe-static/@domain-group/fe-brary/static/fonts/bolton/F37Bolton-Bold.woff2" as="font" type="font/woff2" crossorigin="true"><title>Sold 970 Drummond Street, Carlton North VIC 3054 on 15 May 2021 - 2016951081 | Domain</title><meta name="description" content="970 Drummond Street, Carlton North VIC 3054 a 2 bedroom, 1 bathroom house sold for $2,255,000 on 2021-04-21T12:54:33.173. View listing details #2016951081 on Domain"><link rel="manifest" href="/manifest.json"><meta name="theme-color" content="#0ea800"><link rel="canonical" href="https://www.domain.com.au/970-drummond-street-carlton-north-vic-3054-2016951081"><meta property="og:title" content="Sold 970 Drummond Street, Carlton North VIC 3054 on 15 May 2021 - 2016951081 | Domain"><meta property="og:description" content="970 Drummond Street, Carlton North VIC 3054 a 2 bedroom, 1 bathroom house sold for $2,255,000 on 2021-04-21T12:54:33.173. View listing details #2016951081 on Domain"><meta property="og:type" content="product"><meta property="og:site_name" content="Domain"><meta property="og:url" content="https://www.domain.com.au/970-drummond-street-carlton-north-vic-3054-2016951081"><meta property="og:image" content="https://bucket-api.domain.com.au/v1/bucket/image/2016951081_1_1_210421_025433-w1600-h1067"><meta property="fb:app_id" content="505328276158724"><meta property="al:ios:url" content="domain.com.au://propertyDetails/2016951081"><meta property="al:ios:app_store_id" content="319908646"><meta property="al:ios:app_name" content="Domain Real Estate and Property"><meta property="al:android:url" content="domain://listing/2016951081"><meta property="al:android:package" content="com.fairfax.domain"><meta property="al:android:app_name" content="Domain"><meta name="twitter:card" content="gallery"><meta name="twitter:site" content="@Domaincomau"><meta name="twitter:title" content="Sold 970 Drummond Street, Carlton North VIC 3054 on 15 May 2021 - 2016951081 | Domain"><meta name="twitter:description" content="970 Drummond Street, Carlton North VIC 3054 a 2 bedroom, 1 bathroom house sold for $2,255,000 on 2021-04-21T12:54:33.173. View listing details #2016951081 on Domain"><meta name="twitter:image0" content="https://bucket-api.domain.com.au/v1/bucket/image/2016951081_1_1_210421_025433-w1600-h1067"><meta name="twitter:image1" content="https://bucket-api.domain.com.au/v1/bucket/image/2016951081_2_1_210421_025433-w1600-h1067"><meta name="twitter:image2" content="https://bucket-api.domain.com.au/v1/bucket/im ...

# %%
browser = initialise_browser()

# retrieve page with the requests module and visit url
response = requests.get(url)
browser.visit(url)

# getting the html code of browser
html = browser.html

print(html)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# [WDM] - Driver [C:\Users\TechFast Australia\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# <html lang="en-AU" data-version="8.15.239" data-build-git-hash="a926c9564214b38755c8b0ae458366efcd6a3bfb" data-build-time="Fri May 21 2021 10:26:01 GMT+1000 (Australian Eastern Standard Time)" data-build-id="master-3493"><head><link rel="dns-prefetch" href="//ads.rubiconproject.com"><link rel="dns-prefetch" href="//fastlane.rubiconproject.com"><meta charset="utf-8"><meta http-equiv="content-language" content="en-au"><meta name="format-detection" content="telephone=no"><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta name="viewport" content="width=device-width, initial-scale=1"><link rel="dns-prefetch" href="//static.domain.com.au"><link rel="dns-prefetch" href="//rimh2.domainstatic.com.au"><meta name="apple-mobile-web-app-capable" content="yes"><meta name="theme-color" content="#0ea800"><link rel="apple-touch-icon-precomposed" href="https://static.domain.com.au/domain/54.png"><link rel="apple-touch-icon-precomposed" href="https://static.domain.com.au/domain/72.png"><link rel="apple-touch-icon-precomposed" href="https://static.domain.com.au/domain/114.png"><link rel="apple-touch-icon-precomposed" href="https://static.domain.com.au/domain/144.png"><link rel="shortcut icon" href="https://static.domain.com.au/domain/favicon.ico"><link rel="preload" href="https://static.domain.com.au/content/fe-static/@domain-group/fe-brary/static/fonts/bolton/F37Bolton-Regular.woff2" as="font" type="font/woff2" crossorigin="true"><link rel="preload" href="https://static.domain.com.au/content/fe-static/@domain-group/fe-brary/static/fonts/bolton/F37Bolton-Bold.woff2" as="font" type="font/woff2" crossorigin="true"><title>57 Curtin Ave, Abbotsford NSW 2046 | Domain</title><meta name="description" content="3 bedroom house for Sale at 57 Curtin Ave, Abbotsford NSW 2046. View property photos, floor plans, local school catchments &amp; lots more on Domain.com.au. 2016992421"><link rel="manifest" href="/manifest.json"><meta name="theme-color" content="#0ea800"><link rel="canonical" href="https://www.domain.com.au/57-curtin-ave-abbotsford-nsw-2046-2016992421"><meta property="og:title" content="57 Curtin Ave, Abbotsford NSW 2046 | Domain"><meta property="og:description" content="3 bedroom house for Sale at 57 Curtin Ave, Abbotsford NSW 2046. View property photos, floor plans, local school catchments &amp; lots more on Domain.com.au. 2016992421"><meta property="og:type" content="product"><meta property="og:site_name" content="Domain"><meta property="og:url" content="https://www.domain.com.au/57-curtin-ave-abbotsford-nsw-2046-2016992421"><meta property="og:image" content="https://bucket-api.domain.com.au/v1/bucket/image/2016992421_1_1_210509_112438-w3200-h2133"><meta property="fb:app_id" content="505328276158724"><meta property="al:ios:url" content="domain.com.au://propertyDetails/2016992421"><meta property="al:ios:app_store_id" content="319908646"><meta property="al:ios:app_name" content="Domain Real Estate and Property"><meta property="al:android:url" content="domain://listing/2016992421"><meta property="al:android:package" content="com.fairfax.domain"><meta property="al:android:app_name" content="Domain"><meta name="twitter:card" content="gallery"><meta name="twitter:site" content="@Domaincomau"><meta name="twitter:title" content="57 Curtin Ave, Abbotsford NSW 2046 | Domain"><meta name="twitter:description" content="3 bedroom house for Sale at 57 Curtin Ave, Abbotsford NSW 2046. View property photos, floor plans, local school catchments &amp; lots more on Domain.com.au. 2016992421"><meta name="twitter:image0" content="https://bucket-api.domain.com.au/v1/bucket/image/2016992421_1_1_210509_112438-w3200-h2133"><meta name="twitter:image1" content="https://bucket-api.domain.com.au/v1/bucket/image/2016992421_2_1_210509_112438-w3200-h2133"><meta name="twitter:image2" content="https://bucket-api.domain.com.au/v1/bucket/image/2016992421_3_1_210509_112438-w3200-h2133"><meta name="twitter:image3" content="https://bucket-api.domain.com.au/v1/bucket/image/2016 ...
#     .expander__gradient { display: none !important; }
#     .expander__wrapper { max-height: none !important; }
#     .expander-content { height: auto !important; }
#   </style></noscript><script type="text/javascript" async="" src="//www.googleadservices.com/pagead/conversion_async.js" nonce=""></script><script type="text/javascript" async="" src="//www.googleadservices.com/pagead/conversion_async.js" nonce=""></script><script async="" data-jsonpid="" src="https://cdn-gl.imrworldwide.com/novms/js/2/nlsSDK600.bundle.min.js"></script><script async="true" type="text/javascript" src="https://sslwidget.criteo.com/event?a=4866&amp;v=5.6.3&amp;p0=e%3Dexd%26site_type%3Dd&amp;p1=e%3Dvp%26p%3D2016992421&amp;p2=e%3Ddis&amp;adce=1&amp;tld=domain.com.au&amp;dtycbr=8176" data-owner="criteo-tag"></script><script async="" src="https://cdn-gl.imrworldwide.com/conf/PF5073599-31A3-4F8A-98F7-B83D5B444D71.js#name=PF5073599-31A3-4F8A-98F7-B83D5B444D71&amp;ns=NOLBUNDLE"></script><script async="" src="https://s.pinimg.com/ct/lib/main.c8288b79.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js" nonce=""></script><script type="text/javascript" async="" src="https://www.google-analytics.com/plugins/ua/linkid.js" nonce=""></script><script async="" src="https://adc-js.nine.com.au/adc.js"></script><script async="" type="text/javascript" src="//ads.pubmatic.com/AdServer/js/pwt/159133/2355/pwt.js"></script><script async="" src="https://s.pinimg.com/ct/core.js"></script><script src="https://connect.facebook.net/signals/config/220193701513207?v=2.9.40&amp;r=stable" async=""></script><script async="" src="//connect.facebook.net/en_US/fbevents.js"></script><script type="text/javascript" async="" src="https://static.hotjar.com/c/hotjar-966278.js?sv=7" nonce=""></script><script type="text/javascript" async="" src="https://bat.bing.com/bat.js" nonce=""></script><script type="text/javascript" async="" src="//www.googleadservices.com/pagead/conversion_async.js" nonce=""></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-HFSVJ1Z577&amp;l=dataLayer&amp;cx=c" nonce=""></script><script type="text/javascript" async="" src="https://www.google-analytics.com/gtm/js?id=GTM-T6X56MC&amp;cid=738153624.1621650326" nonce=""></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-M3HVG4"></script><script async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" src="https://cdn.branch.io/branch-latest.min.js"></script><script async="" src="//cdn.raygun.io/raygun4js/raygun.min.js"></script><script>
#         !function(a,b,c,d,e,f,g,h){a.RaygunObject=e,a[e]=a[e]||function(){
#         (a[e].o=a[e].o||[]).push(arguments)},f=b.createElement(c),g=b.getElementsByTagName(c)[0],
#         f.async=1,f.src=d,g.parentNode.insertBefore(f,g),h=a.onerror,a.onerror=function(b,c,d,f,g){
#         h&&h(b,c,d,f,g),g||(g=new Error(b)),a[e].q=a[e].q||[],a[e].q.push({
#         e:g})}}(window,document,"script","//cdn.raygun.io/raygun4js/raygun.min.js","rg4js");
#
#         rg4js('apiKey', 'Jc2EG8UJC5PYaGq58+JtVA==');
#         rg4js('enableCrashReporting', true);
#         rg4js('enablePulse', false);
#         rg4js('options', {
#           ignore3rdPartyErrors: true,
#           excludedHostnames: ['www.googletagmanager.com']
#         });
#         rg4js('withTags', ["isListingDetails","isResidentialListingDetails"])
#         rg4js('setVersion', '8.15.239');
#         </script><script src="//cdn.parsely.com/keys/domain.com.au/p.js" async=""></script><script type="application/ld+json">[{"@context":"http://schema.org","@type":"Organization","name":"Domain","url":"https://www.domain.com.au","sameAs":["https://www.facebook.com/domain.com.au","https://twitter.com/domaincomau","https://plus.google.com/+domaincomau","https://www.linkedin.com/company/domain-com-au"]},{"@context":"http://schema.org","@type":"Residence","address":{"@type":"PostalAddress","streetAddress":"57 Curtin Ave","addressLocality":"Abbotsford","addressRegion":"NSW","postalCode":"2046"}},{"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https://www.domain.com.au/sale/","name":"Sale"}},{"@type":"ListItem","position":2,"item":{"@id":"https://www.domain.com.au/sale/nsw/","name":"NSW"}},{"@type":"ListItem","position":3,"item":{"@id":"https://www.domain.com.au/sale/abbotsford-nsw-2046/","name":"Abbotsford"}},{"@type":"ListItem","position":4,"item":{"@id":"https://www.domain.com.au/sale/abbotsford-nsw-2046/free-standing/","name":"Free Standing Houses"}},{"@type":"ListItem","position":5,"item":{"@id":"https://www.domain.com.au/sale/abbotsford-nsw-2046/free-standing/3-bedrooms/","name":"3-Bedrooms"}},{"@type":"ListItem","position":6,"item":{"@id":"https://www.domain.com.au/57-curtin-ave-abbotsford-nsw-2046-2016992421","name":"57 Curtin Ave, Abbotsford NSW 2046"}}]},{"@context":"http://schema.org","@type":"Event","location":{"@type":"Residence","geo":{"@type":"GeoCoordinates","latitude":-33.8544585,"longitude":151.1319226},"name":"57 Curtin Ave, Abbotsford NSW 2046","address":{"@type":"PostalAddress","addressLocality":"Abbotsford","addressRegion":"NSW","postalCode":"2046","streetAddress":"57 Curtin Ave"}},"name":"Inspection","description":"Inspect 57 Curtin Ave","url":"https://www.domain.com.au/57-curtin-ave-abbotsford-nsw-2046-2016992421","image":"https://bucket-api.domain.com.au/v1/bucket/image/2016992421_1_1_210509_112438-w3200-h2133","startDate":"2021-05-22T13:00:00","endDate":"2021-05-22T13:40:00"},{"@context":"http://schema.org","@type":"Event","location":{"@type":"Residence","geo":{"@type":"GeoCoordinates","latitude":-33.8544585,"longitude":151.1319226},"name":"57 Curtin Ave, Abbotsford NSW 2046","address":{"@type":"PostalAddress","addressLocality":"Abbotsford","addressRegion":"NSW","postalCode":"2046","streetAddress":"57 Curtin Ave"}},"name":"Inspection","description":"Inspect 57 Curtin Ave","url":"https://www.domain.com.au/57-curtin-ave-abbotsford-nsw-2046-2016992421","image":"https://bucket-api.domain.com.au/v1/bucket/image/2016992421_1_1_210509_112438-w3200-h2133","startDate":"2021-05-29T13:00:00","endDate":"2021-05-29T13:40:00"},{"@context":"http://schema.org","@type":"Event","location":{"@type":"Residence","geo":{"@type":"GeoCoordinates","latitude":-33.8544585,"longitude":151.1319226},"name":"57 Curtin Ave, Abbotsford NSW 2046","address":{"@type":"PostalAddress","addressLocality":"Abbotsford","addressRegion":"NSW","postalCode":"2046","streetAddress":"57 Curtin Ave"}},"name":"Inspection","description":"Inspect 57 Curtin Ave","url":"https://www.domain.com.au/57-curtin-ave-abbotsford-nsw-2046-2016992421","image":"https://bucket-api.domain.com.au/v1/bucket/image/2016992421_1_1_210509_112438-w3200-h2133","startDate":"2021-06-05T13:00:00","endDate":"2021-06-05T13:30:00"},{"@context":"http://schema.org","@type":"Event","location":{"@type":"Residence","geo":{"@type":"GeoCoordinates","latitude":-33.8544585,"longitude":151.1319226},"name":"57 Curtin Ave, Abbotsford NSW 2046","address":{"@type":"PostalAddress","addressLocality":"Abbotsford","addressRegion":"NSW","postalCode":"2046","streetAddress":"57 Curtin Ave"}},"name":"Auction","description":"Auction at 57 Curtin Ave","url":"https://www.domain.com.au/57-curtin-ave-abbotsford-nsw-2046-2016992421","image":"https://bucket-api.domain.com.au/v1/bucket/image/2016992421_1_1_210509_112438-w3200-h2133","startD ...
#           // load Branch
#           (function(b,r,a,n,c,h,_,s,d,k){if(!b[n]||!b[n]._q){for(;s<_.length;)c(h,_[s++]);d=r.createElement(a);d.async=1;d.src="https://cdn.branch.io/branch-latest.min.js";k=r.getElementsByTagName(a)[0];k.parentNode.insertBefore(d,k);b[n]=h}})(window,document,"script","branch",function(b,r){b[r]=function(){b._q.push([r,arguments])}},{_q:[],_v:1},"addListener applyCode autoAppIndex banner closeBanner closeJourney creditHistory credits data deepview deepviewCta first getCode init link logout redeem referrals removeListener sendSMS setBranchViewData setIdentity track validateCode trackCommerceEvent logEvent disableTracking".split(" "), 0);
#           // init Branch
#           branch.init('key_live_beUO960ie7SgOCONK8dfVgboqqe0mcGG');
#         </script><script src="https://accounts.google.com/gsi/client" async="" defer=""></script><script>bazadebezolkohpepadr="1921357594"</script><script type="text/javascript" src="https://www.domain.com.au/akam/11/72859693" defer=""></script><style data-emotion="css-global"></style><style data-emotion-css="1htgcm6">.css-1htgcm6{position:fixed;width:1px;height:1px;padding:19px 0;-webkit-clip:rect(1px,1px,1px,1px);clip:rect(1px,1px,1px,1px);-webkit-transition:background 0.2s linear;transition:background 0.2s linear;color:#fff;font-size:16px;line-height:24px;text-align:center;-webkit-text-decoration:none;text-decoration:none;overflow:hidden;z-index:10000;}.css-1htgcm6:focus,.css-1htgcm6:active{width:100%;height:auto;-webkit-clip:auto;clip:auto;background:#22365a;color:#fff;-webkit-text-decoration:none;text-decoration:none;}</style><style data-emotion-css="soiaw8">.css-soiaw8:before{display:inline-block;width:1px;height:14px;margin:-2px 20px;background:rgba(255,255,255,0.3);content:'';}</style><style data-emotion-css="16q9xmc">.css-16q9xmc{position:absolute;width:1px;height:1px;margin:-1px;padding:0;-webkit-clip:rect(1px,1px,1px,1px);clip:rect(1px,1px,1px,1px);border:0;overflow:hidden;-webkit-clip-path:inset(100%);clip-path:inset(100%);-webkit-clip-path:none;}</style><style data-emotion-css="in3yi3">.css-in3yi3{font-weight:bold;}</style><style data-emotion-css="1ktrj7">.css-1ktrj7{color:#3c475b;}@media(max-width:623px){.css-1ktrj7 .share-tools__inner{-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}}</style><style data-emotion-css="f54a6h">.css-f54a6h{width:100%;background:#fff no-repeat;}.css-f54a6h.is-transparent{background:0;}@media (min-width:1021px) and (max-width:1105px){.css-f54a6h{font-size:14px;}}</style><style data-emotion="css-global"></style><style data-emotion-css="xl8z15">.css-xl8z15{opacity:0;visibility:hidden;position:fixed;top:0;right:0;left:0;width:100%;height:100%;background:rgba(11,32,71,0.8);-webkit-transition:visibility 0s linear,0.25s opacity 0.25s ease-in-out;transition:visibility 0s linear,0.25s opacity 0.25s ease-in-out;z-index:200;}.mobile-nav-open .css-xl8z15{opacity:1;visibility:visible;-webkit-transition:visibility 0s linear 0s,opacity 0.25s ease-in-out;transition:visibility 0s linear 0s,opacity 0.25s ease-in-out;}@media(min-width:1021px){.mobile-nav-open .css-xl8z15{opacity:0;visibility:hidden;}}</style><style data-emotion-css="a5sdz5">.css-a5sdz5{background-color:#f2f5f7;}@media(max-width:1020px){.css-a5sdz5{display:none;}}</style><style data-emotion-css="eijyrs">.css-eijyrs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0 24px;height:24px;max-width:1280px;margin:0 auto;}</style><style data-emotion-css="1ksjyp9">.css-1ksjyp9{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-align-self:stretch;-ms-flex-item-align:stretch;align-self:stretch;padding-right:8px;margin-right:8px;border-right:1px solid #d0d3d9;}</style><style data-emotion-css="1xvzo5j">.css-1xvzo5j{width:81px;height:18px;}</style><style data-emotion-css="1rn0l2q">.css-1rn0l2q{fill:#7e8594;}</style><style data-emotion-css="16sh9nl">.css-16sh9nl{color:inherit;-webkit-text-decoration:inherit;text-decoration:inherit;color:#7e8594;font-size:12px;line-height:18px;}.css-16sh9nl:hover,.css-16sh9nl:focus,.css-16sh9nl:visited,.css-16sh9nl:active{color:inherit;-webkit-text-decoration:inherit;text-decoration:inherit;}.css-16sh9nl:visited{color:#7e8594;}.css-16sh9nl:not(:last-child)::after{content:'|';margin:0 3px;}</style><style data-emotion-css="1uh13z5">.css-1uh13z5{min-height:40px;position:relative;width:100%;}@media(max-width:1020px){.css-1uh13z5{min-heig ...
# /*# sourceURL=/_/gsi/_/ss/k=gsi.gsi.pWkS2-m9kRQ.L.W.O/am=cg/d=1/rs=AF0KOtXrpFFUv-r6iMK1HX1aJl2SBuMmKw/m=gis_client_button_style */</style><script async="" src="//resources.xg4ken.com/js/v2/ktag.js?tid=KT-N3B0B-3EB"></script><script async="" src="https://script.hotjar.com/modules.0d0a898aa455aaa7acd5.js" charset="utf-8"></script><style type="text/css">iframe#_hjRemoteVarsFrame {display: none !important; width: 1px !important; height: 1px !important; opacity: 0 !important; pointer-events: none !important;}</style><script src="https://bat.bing.com/p/action/4073566" type="text/javascript" async=""></script><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/880850510/?random=1621650326402&amp;cv=9&amp;fst=1621650326402&amp;num=1&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;eid=2505059650&amp;u_h=1235&amp;u_w=2195&amp;u_ah=1195&amp;u_aw=2195&amp;u_cd=24&amp;u_his=2&amp;u_tz=600&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wg5c1&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.domain.com.au%2F57-curtin-ave-abbotsford-nsw-2046-2016992421&amp;tiba=57%20Curtin%20Ave%2C%20Abbotsford%20NSW%202046%20%7C%20Domain&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4" nonce=""></script><script async="" src="https://cdn-gl.imrworldwide.com/novms/js/2/configs/glcfg510.js"></script><meta http-equiv="origin-trial" content="A+b/H0b8RPXNaJgaNFpO0YOFuGK6myDQXlwnJB3SwzvNMfcndat4DZYMrP4ClJIzYWo3/yP2S+8FTZ/lpqbPAAEAAABueyJvcmlnaW4iOiJodHRwczovL2ltYXNkay5nb29nbGVhcGlzLmNvbTo0NDMiLCJmZWF0dXJlIjoiVHJ1c3RUb2tlbnMiLCJleHBpcnkiOjE2MjYyMjA3OTksImlzVGhpcmRQYXJ0eSI6dHJ1ZX0="><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content="A7+rMYR5onPnACrz+niKSeFdH3xw1IyHo2AZSHmxrofRk9w4HcQPMYcpBUKu6OQ6zsdxf4m/vqa6tG6Na4OLpAQAAAB4eyJvcmlnaW4iOiJodHRwczovL2ltYXNkay5nb29nbGVhcGlzLmNvbTo0NDMiLCJmZWF0dXJlIjoiQ29udmVyc2lvbk1lYXN1cmVtZW50IiwiZXhwaXJ5IjoxNjI2MjIwNzk5LCJpc1RoaXJkUGFydHkiOnRydWV9"><meta http-equiv="origin-trial" content="AwfG8hAcHnPa/kJ1Co0EvG/K0F9l1s2JZGiDLt2mhC3QI5Fh4qmsmSwrWObZFbRC9ieDaSLU6lHRxhGUF/i9sgoAAACBeyJvcmlnaW4iOiJodHRwczovL2RvdWJsZWNsaWNrLm5ldDo0NDMiLCJmZWF0dXJlIjoiSW50ZXJlc3 ...
#       17 other 3 bedroom house</a> in Abbotsford have recently been sold. </p></div></div></div><div class="css-urbgr8"><div><div data-testid="feedback-form-modal-btn" class="css-1dra2ks"><div><button type="button" class="css-5lbcze"><span class="css-1fjztun"><svg viewBox="0 0 24 24" aria-hidden="true" class="domain-icon css-jeyium"><path fill="none" stroke="currentColor" stroke-width="2" d="M5 3v18m0-6h15l-3-5 3-5H5v10z"></path></svg></span><span class="css-1s26z8e">Report Listing</span></button></div></div><div class="css-xn3w06"><div class="css-1fkb39v" data-testid="messages__toast"><div></div></div></div></div></div></div><aside data-testid="listing-details__right-column" class="css-1pwoa1a"><div name="enquiry-form" id="enquiry-form"><div data-testid="listing-details__agent-details" class="css-1fpeun9"><div class="css-9keu3t"><div data-testid="listing-details__agent-details-carousel with-big-agents" class="css-qae1sp"><button type="button" data-testid="listing-details__agent-details-left-arrow" class="css-19cucft"><svg class="domain-icon css-1d7ezy6" viewBox="0 0 24 24" aria-hidden="true"><path fill="none" stroke="currentColor" stroke-width="2" d="M15 5l-7 7 7 7"></path></svg></button><div data-testid="listing-details__agent-details-agent" class="css-16uvv0"><a data-testid="listing-details__agent-details-agent-photo" href="https://www.domain.com.au/real-estate-agent/sam-varrica-883547/"><div class="css-1ua712w"><img data-testid="fe-co-avatar--image" src="https://rimh2.domainstatic.com.au/yb9Od4iunx4xJWNGX5N-0-t1bQs=/120x120/top/filters:format(jpeg):quality(80):no_upscale()/https://images.domain.com.au/img/16640/contact_883547.jpeg?date=637572764719000000" class="css-6jrdpz"></div></a><div class="css-1ensggs"><a data-testid="listing-details__agent-details-agent-name" class="css-8q9rby" href="https://www.domain.com.au/real-estate-agent/sam-varrica-883547/">Sam Varrica</a><a data-testid="listing-details__agent-details-agent-company-name" class="css-1fjxwer" href="https://www.domain.com.au/real-estate-agencies/rainehornefivedock-16640/">Raine &amp; Horne Five Dock</a></div></div><button type="button" data-testid="listing-details__agent-details-right-arrow" class="css-g8h60v"><svg class="domain-icon css-1d7ezy6" viewBox="0 0 24 24" aria-hidden="true"><path fill="none" stroke="currentColor" stroke-width="2" d="M9 5l7 7-7 7"></path></svg></button></div></div><div class="css-vr7q1b"><button type="button" class="css-1s3v9vb" data-testid="listing-details__phone-cta-button outline"><span class="css-1fjztun"><svg viewBox="0 0 24 24" aria-hidden="true" class="domain-icon css-jeyium"><g fill="none"><path d="M10.2 7.5a1 1 0 0 0 0-1.4L7.8 3.7a2.4 2.4 0 0 0-3.4 0l-.5.5a3.6 3.6 0 0 0-.4 4.3 25.3 25.3 0 0 0 12 12 3.7 3.7 0 0 0 4.3-.4l.5-.5a2.4 2.4 0 0 0 0-3.4l-2.4-2.4a1 1 0 0 0-1.4 0l-1.4 1.4a8.5 8.5 0 0 1-6.2-6.4z" stroke="currentColor" stroke-width="2"></path><path d="M0 0h24v24H0z"></path></g></svg></span><span class="css-1s26z8e"><span>Call</span></span></button></div><a style="background-color:#F9AE00" class="css-78g41m" href="https://www.domain.com.au/real-estate-agencies/rainehornefivedock-16640/"><img data-testid="listing-details__agent-details-branding-lazy" src="https://rimh2.domainstatic.com.au/Qqtr-CG6Rb6S7pVGFH-1b8wAcbY=/200x70/filters:format(jpeg):quality(80):no_upscale()/https://images.domain.com.au/img/Agencys/16640/logo_16640.png?date=131097622137437775?date=637572777668187722" alt="Raine &amp; Horne Five Dock's logo" class="css-gaitid"></a><div data-testid="listing-details__agent-details-cta-box" class="css-1cy2hkj"><div class="css-2b0zyx"><button type="button" class=" css-8rqdw3" data-testid="listing-details__cta-button highlight"><span class="css-1fjztun"><svg viewBox="0 0 24 24" aria-hidden="true" class="domain-icon css-jeyium"><rect x="2" y="5" width="20" height="14" rx="2" ry="2" fill="none" stroke="currentColor" stroke-width="2"></rect><path fill="none" stroke="currentColor" d="M18.5 8.5l-6.5 5-6.5-5m0 7l3-2m10 2l-3-2 ...
#       Find out your estimated
#       <span class="descriptionHighlights">borrowing power</span>
#       and the loans you could get from
#       <span class="descriptionHighlights">35+ lenders</span>.
#     </p></div></div><div class="css-kdt4xp"><a target="_blank" rel="noopener noreferrer" href="https://www.domain.com.au/loanfinder/basics/new-home/?ltm_source=domain&amp;ltm_content=GetEval-newloan-NotPIM&amp;ltm_campaign=domain_buy-listing_StatusCard_CTA_web&amp;ltm_term=NotPIM&amp;ltm_medium=StatusCard_CTA" class="css-gdfue7">Get a home loan evaluation</a></div></div><div class="css-1kz4mnk"><div data-testid="status-card--secondary-card" class="css-18ryolu"><div class="css-1b98lu3"><img alt="" src="https://static.domain.com.au/content/fe-static/@domain-group/fe-dlf-components/static/sam_dea63c3a.png" class="css-j9vdrt"><span>Sam</span></div><h3 class="css-xufdpr">Talk to an expert</h3><div class="css-625hjr">Explore your options with a Domain Home Loans Home Loan Specialist.</div><div class="css-1hdjrz5"><a href="https://www.domain.com.au/loanfinder/appointment-booking/appointment-select/?ltm_source=domain&amp;ltm_content=Schedule-bookfunnel-NotPIM&amp;ltm_campaign=domain_buy-listing_StatusCard_CTA_web&amp;ltm_term=NotPIM&amp;ltm_medium=StatusCard_CTA" target="_blank" rel="noopener noreferrer" class="css-zpbfeu"><span class="css-1fjztun"><svg class="domain-icon css-skamdd" viewBox="0 0 24 24" aria-hidden="true"><g fill="none"><path d="M10.2 7.5a1 1 0 0 0 0-1.4L7.8 3.7a2.4 2.4 0 0 0-3.4 0l-.5.5a3.6 3.6 0 0 0-.4 4.3 25.3 25.3 0 0 0 12 12 3.7 3.7 0 0 0 4.3-.4l.5-.5a2.4 2.4 0 0 0 0-3.4l-2.4-2.4a1 1 0 0 0-1.4 0l-1.4 1.4a8.5 8.5 0 0 1-6.2-6.4z" stroke="currentColor" stroke-width="2"></path><path d="M0 0h24v24H0z"></path></g></svg></span><span class="css-1s26z8e">Schedule a chat</span></a></div></div><div class="css-unpbbb"><section><div class="css-f6rfz9"><h2 class="css-1jbhcad"><a href="https://www.productreview.com.au/listings/domain-home-loans" target="_blank" rel="nofollow noopener noreferrer"><img src="https://static.domain.com.au/content/fe-static/@domain-group/fe-dlf-components/static/pr-awards-a_bcfd7ab2.svg" alt="product review logo" class="css-v2kfba"></a></h2><div class="css-409ah1"><span class="css-1xdhyk6"><span class="css-1bf5il7">4.8</span><span aria-label="star rating" class="css-jb129p"><span data-testid="active-stars" class="css-y6675x"></span></span></span><p data-testid="tagline" class="css-1fuzeki">From <a href="https://www.productreview.com.au/listings/domain-home-loans" target="_blank" rel="nofollow noopener noreferrer">762 reviews</a> as of Dec 2020</p></div></div></section></div></div></div><div class="css-1j7jh4t"><img alt="" src="https://static.domain.com.au/content/fe-static/@domain-group/fe-dlf-components/static/noCosts_8bf31771.svg" class="css-1uryqm"><button type="button" data-testid="status-card--dlf-fee-button" class="css-yodgg8">No Domain Home Loans fees?</button></div><footer data-testid="status-card--tcs-disclaimer" class="css-zrivu7">Digital Home Loans Pty Ltd t/a Domain Home Loans (ABN 39 619 694 156, Credit Representative 500208) is authorised by Auscred Services Pty Ltd (ABN 50 164 638 171, Australian Credit Licence 442372).</footer></section></div><div><div name="repayments-calculator" class="css-1r8q5rm"><div class="experiment__opacity" style="transition: opacity 250ms ease 0s; opacity: 1;"><div><div class=" css-hg8odh"><div role="tablist" class="css-2g7p9b"><button class=" css-12wr84j" aria-selected="true" role="tab" type="button" data-short-label=""><span>repayments</span></button><button class=" css-va4omk" aria-selected="false" role="tab" type="button" data-short-label=""><span>stamp duty &amp; upfront costs</span></button></div><div class="css-13v3rg8"><div data-testid="dlf-calculators-tab-content" class="css-lcuhl0"><div></div><div><div class="experiment__opacity" style="transition: opacity 250ms ease 0s; opacity: 1;"><div data-testid="calculator-repayments__calculator" class="css-11px1c9"><form method="get" target="_blank" action="https://www.domain.com.au/loanfinder/basics/new-home?ltm_source=domain&amp;ltm_medium=referral&amp;ltm_campaign=domain_r_calculator_buy-listing_web&amp;l ...
# <br>
# <br>
# This calculator is powered by <a href="https://www.domain.com.au/home-loans/" style="color: #a9afba;" target="_blank" rel="noopener noreferrer">Domain Home Loans</a>, credit representative number 500208 <br>
# </span><button type="button" class="css-1djykay">What you need to know about this estimate</button><div data-testid="expander-wrapper" class="noscript-expander-wrapper css-aeox7o" style="max-height: 0px; overflow: hidden;"><div class="noscript-expander-content css-1mnayj9"><div><p>Comparison Rate: [2.9% p.a.]#
# <br>
# <br>
# This calculator is powered by <a href="https://www.domain.com.au/home-loans/" style="color: #a9afba;" target="_blank" rel="noopener noreferrer">
# Domain Home Loans</a> which is the trading
# name of Digital Home Loans Pty Ltd (ACN 619 694 156). Digital Home Loans Pty Ltd is a credit
# representative of Auscred Services Pty Ltd (ACN 164 638 171), a licensed credit assistance
# provider with Australian Credit Licence 442372.
# Domain Operations Pty Ltd (ACN 617 803 460) is making available the calculator and access to Domain
# Home Loans' website as an interactive advertisement only, and is not in any way providing a credit
# service to Domain Home Loans' customers.<br>
# The example price above is not indicative of the potential price of the property. This calculator is
# intended as a guide only based on the information you input. The results should not be considered
# approval for a loan. The repayment amount is an estimate by Domain Home Loans based on a home loan
# product from Domain Home Loans' panel of products. Terms, conditions and lending criteria apply.
# To find out your repayments please contact Domain Home Loans. The calculation also assumes that
# interest rates do not change over the term of the loan and excludes any fees and charges that
# may be charged to your loan, for example, upfront establishment fee, monthly loan service fee
# and lenders Mortgage Insurance/Low Deposit Premium which, if they apply, will add to the cost
# of the loan.<br>
# Most lenders on Domain Home Loans' panel will not lend more than 95% of its valuation of the
# security property. Interest rates and repayment amounts are subject to change. Applications for a
# home loan are subject to approval and satisfactory security. Full terms and conditions will be made
# available by the lender.<br></p></div></div></div><span class="css-ilqb03">
# *Fees and charges are payable.<br>
# #Comparison rates are calculated on a secured loan of $150,000 over 25 years.
# WARNING: This comparison rate is true only for the examples given and may not include all fees and
# charges. Different terms, fees or other loan amounts might result in a different comparison rate.</span></div></div></div></div></div></div></div></div></div></div></div><section class="css-801oh8"><section class="css-1785rop"><h4 class="css-1fw0sk4">Insurance</h4><div class="css-18n3akp"><h5 data-testid="domain-insure-title" class="css-9u6mlw">A home insurance quote in 2 mins? Sure!</h5><p class="css-wpl4uy">Get yours with Domain Insure.</p><div class="css-geek62"><svg viewBox="0 0 24 24" class="domain-icon css-12dqztl" aria-hidden="true"><path fill="none" stroke="currentColor" stroke-width="2" d="M10.027 0.804779L18.5489 6.40101L16.624 7.52966L10.0235 3.19519L3.0313 7.758C3.18475 10.1564 3.59016 13.149 4.61301 15.7059C5.69371 18.4074 7.37877 20.4373 10.021 20.9811C11.8819 20.5789 13.3258 19.3318 14.4248 17.7308C15.56 16.0771 16.2646 14.1303 16.624 12.6386L18.5684 13.107C18.1707 14.7575 17.3864 16.9503 16.0737 18.8627C14.7594 20.7773 12.8531 22.4949 10.2068 22.9834L10.0287 23.0162L9.85042 22.9846C6.13534 22.3249 3.98556 19.5221 2.75608 16.4487C1.52748 13.3775 1.12931 9.8429 1.00126 7.28693L0.972519 6.7133L10.027 0.804779Z"></path></svg><a data-testid="domain-insure-driver-cta" href="https://www.domain.com.au/insurance?ltm_source=domain&amp;ltm_medium=drivercard&amp;ltm_campaign=domain_buy-listing&amp;ltm_term=get-a-quote&amp;ltm_content=how-much-costs" target="_blank" rel="noopener noreferrer" class="css-bt34nb">Get an insurance quote</a><svg viewBox="0 0 18 18" aria-hidden="true" class="domain-icon css-kry84i"><path d="M12.5 9.5v2a1 1 0 0 1-1 1h-5a1 1 0 0 1-1-1v-5a1 1 0 0 1 1-1h2M10.5 4.5h3v3M13.3 4.7L9.5 8.5" fill="none" stroke="currentColor"></path></svg></div></div></section></section><div></div><div name="listing-details__school-catchment" data-testid="listing-details__school-catchment" class="css-18he1zu"><div><h2>School Catchment Zones for 57 Curtin Ave</h2><div data-testid="listing-details__school-catchment-content" class="css-ckdcyi"><section class="school-catchment"><div role="tablist" class="css-2g7p9b"><button class="css-n9veyx" aria-selected="true" role="tab" type="button" data-short-label=""><span>All</span></button><button class="css-1cnthm0" aria-selected="false" role="tab" type="button" data-short-label=""><span>Primary</span></button><button class="css-1cnthm0" aria-selected="false" role="tab" type="button" data-short-label=""><span>Secondary</span></button><button class="css-1cnthm0" aria-selected="false" role="tab" type="button" data-short-label=""><span>Private</span></button><button class="css-1cnthm0" aria-selected="false" role="tab" type="button" data-short-label=""><span>Childcare<span class="css-eoy0ek">NEW</span></span></button></div><div data-testid="fe-co-school-catchment-content"><div data-testid="fe-co-school-catchment-category-heading" class="css-er27os"><h4 data-testid="fe-co-school-catchment-category-heading-title" class="css-d5e4fw">Government School Catchment</h4></div><ul><li data-testid="fe-co-school-catchment-school"><div itemscope="" itemtype="http://schema.org/EducationalOrganization" class="css-1nzghr"><div class="css-1fjn8ax"><div class="css-chx01x"><div class="css-tybb00"><h5 itemprop="name" data-testid="fe-co-school-catchment-school-title" class="css-5w5cop">Abbotsford Public School</h5></div><div data-testid="fe-co-school-catchment-schoolDistance" class="css-si4svp">0.2 km<!-- --> away</div><ul class="css-145pu12"><li id="year" data-testid="fe-co-school-catchment-tags" class="css-krkvgm">K-6</li><li id="gender" data-testid="fe-co-school-catchment-tags" class="css-11nkuzb">CoEd</li><li id="type" data-testid="fe-co-school-catchment-tags" class="css-vkb7rn">Government</li></ul></div><a href="/school-catchment/abbotsford-public-school-nsw-2046-59" title="Abbotsford Public School" aria-label="View school profile for Abbotsford Public School" class="css-uttv6y"><span class="css-66mz0q">View Catchment</span><svg viewBox="0 0 18 18" class="domain-icon css-1n668hv" aria-hidden="true"><path ...
# <script type="text/javascript" src="https://static.domain.com.au/fe-server-search-listings/master-3493/static/195fff2ad613dbebdc33.js" defer="defer"></script>
# <script type="text/javascript" src="https://static.domain.com.au/fe-server-search-listings/master-3493/static/4cb107e1a88ede8d32ca.js" defer="defer"></script>
# <script type="text/javascript" src="https://static.domain.com.au/fe-server-search-listings/master-3493/static/fef48845531cfe8c6108.js" defer="defer"></script>
# <script type="text/javascript" src="https://static.domain.com.au/fe-server-search-listings/master-3493/static/96b61808b6c176db9e9b.js" defer="defer"></script>
# <script type="text/javascript" src="https://static.domain.com.au/fe-server-search-listings/master-3493/static/main.5ce4ccb9a1e3527db4fb.js" defer="defer"></script></div><script>var digitalData = {"page":{"pageInfo":{"agencyId":16640,"author":16640,"pageId":2016992421,"pageName":"property details - buy - 2016992421 - 57 curtin ave abbotsford nsw 2046","effectiveDate":"2021-05-10T09:24:37.893","issueDate":"2021-05-10T09:24:37.893","property":{"saleMethod":"auction","address":"57 Curtin Ave, Abbotsford NSW 2046","adtype":"premiumPlus","agency":"Raine \u0026 Horne Five Dock","agencyId":16640,"agentNames":"Sam Varrica, Chris Haliloglu","bathrooms":2,"bedrooms":3,"inspectionsCount":3,"hasPhoto":true,"hasFloorplan":true,"hasDisplayPrice":true,"hasDescription":true,"hasSOI":false,"landArea":470,"virtualTour":false,"floorPlansCount":1,"images":["https://bucket-api.domain.com.au/v1/bucket/image/2016992421_1_1_210509_112438-w3200-h2133","https://bucket-api.domain.com.au/v1/bucket/image/2016992421_2_1_210509_112438-w3200-h2133","https://bucket-api.domain.com.au/v1/bucket/image/2016992421_3_1_210509_112438-w3200-h2133","https://bucket-api.domain.com.au/v1/bucket/image/2016992421_4_1_210509_112438-w3200-h2133","https://bucket-api.domain.com.au/v1/bucket/image/2016992421_5_1_210509_112438-w3200-h2133","https://bucket-api.domain.com.au/v1/bucket/image/2016992421_6_1_210509_112438-w3200-h2133","https://bucket-api.domain.com.au/v1/bucket/image/2016992421_7_1_210509_112438-w3200-h2133","https://bucket-api.domain.com.au/v1/bucket/image/2016992421_8_1_210509_112438-w3200-h2133"],"onlineAuctionAvailable":"None","parking":3,"photoCount":8,"postcode":"2046","price":"Auction","primaryPropertyType":"House","structuredFeatures":[],"propertyId":"BJ-9816-KX","secondaryPropertyType":"House","state":"NSW","suburb":"Abbotsford","videoCount":1,"x-message":"domain-propertyinfo"},"suburbId":32,"isEmbeddedApp":false,"source":"Unknown","brand":"domain","generator":"DO","sysEnv":"responsive"},"category":{"primaryCategory":"Buy","subCategory1":"Property Details","pageType":"Listing"},"optimize":{"shortlistExperimentFlag":true}},"titan":{"adZone":"buy/details","contentWidth":"","adKeyValues":{"cat":"buy","cat1":"details","ctype":"listing","e":"www.domain.com.au","locstate":"nsw","locarea":["inner_west"],"locsuburb":["abbotsford"],"locpostcode":["2046"],"pageId":2016992421,"pageName":"property details - buy - 2016992421 - 57 curtin ave abbotsford nsw 2046","address":"57 Curtin Ave, Abbotsford NSW 2046","usertype":"buy","medianPrice":"1950K","proptypes":["house"],"bedrooms":3},"adSite":"DOMAIN.COM.AU","adSlots":[]},"adLoader":"prebid","version":"1.0","events":[],"user":{"membershipType":"visitor","membershipState":"Not_logged_in","ipAddress":"X+ELnwFablUnlMfRGNuL1v3jl/Yz/Ah9dUyf/fqjmcDTd82BBGcwtHBKlz7MLr61"}};
#               var dataLayer = [digitalData];</script><div><script>var googletag=googletag||{};
#           googletag.cmd=googletag.cmd||[];
#           var pbjs=pbjs||{};
#           pbjs.que=pbjs.que||[];</script></div><div><script>var titanEnabled = true;
#   var titanNativeTest = false;</script></div><script>
#           (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#           (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#           m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#           })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#           ga('create', 'UA-22518123-1', 'auto');
#           ga('require', 'GTM-T6X56MC');
#           ga('set', 'exp', 'enableFirstNameStep.1'); // dlfFunnelEnableFirstNameStep
#           ga('set', 'exp', 'shortlist-photo-gallery.0'); // enableShortlistPhotoGallery
#         </script><script>
#         (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-M3HVG4');
#         </script><noscript><img src="https://www.domain.com.au/akam/11/pixel_72859693?a=dD1lOWE4ZjNkNGE3YWMyZjU0YWU2YWQ0ODZhOWQyNzFkNTk3YjJiY2QxJmpzPW9mZg==" style="visibility: hidden; position: absolute; left: -999px; top: -999px;" /></noscript><script type="text/javascript" nonce="">var _cf = _cf || [];  _cf.push(['_setFsp', true]);  _cf.push(['_setBm', true]);  _cf.push(['_setAu', '/webcontent/47d5e50eui1705e73471c6ea6adfa5']); </script><iframe height="0" width="0" style="display: none; visibility: hidden;" src="//4256018.fls.doubleclick.net/activityi;src=4256018;type=domai627;cat=Domai--7;ord=4398687212193;gtm=2wg5c1;auiddc=791791250.1621650326;~oref=https%3A%2F%2Fwww.domain.com.au%2F57-curtin-ave-abbotsford-nsw-2046-2016992421?"></iframe><script type="text/javascript" nonce="" src="/webcontent/47d5e50eui1705e73471c6ea6adfa5"></script>
# <script type="text/javascript" id="">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","//connect.facebook.net/en_US/fbevents.js");fbq("set","autoConfig","false","220193701513207");fbq("init","220193701513207");fbq("track","PageView");</script>
# <noscript><img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=220193701513207&amp;ev=PageView&amp;noscript=1"></noscript>
#
#
# <script type="text/javascript" id="" src="//secure-au.imrworldwide.com/v60.js"></script><script type="text/javascript" id="">!function(b){if(!window.pintrk){window.pintrk=function(){window.pintrk.queue.push(Array.prototype.slice.call(arguments))};var a=window.pintrk;a.queue=[];a.version="3.0";a=document.createElement("script");a.async=!0;a.src=b;b=document.getElementsByTagName("script")[0];b.parentNode.insertBefore(a,b)}}("https://s.pinimg.com/ct/core.js");pintrk("load","2613638674311");pintrk("page",{page_name:"My Page",page_category:"My Page Category"});</script>
#
# <noscript>
#   <img height="1" width="1" style="display:none;" alt="" src="https://ct.pinterest.com/v3/?tid=2613638674311&amp;noscript=1">
# </noscript>
#
# <script type="text/javascript" id="" src="//cdn-gl.imrworldwide.com/novms/js/2/ggcmb510.js"></script>
# <script type="text/javascript" id="" src="//static.criteo.net/js/ld/ld.js"></script><script type="text/javascript" id="">window.hj=window.hj||function(){(hj.q=hj.q||[]).push(arguments)};hj("trigger","hotjar-premiumplus-listings");</script>
# <script type="text/javascript" id="">!function(c,d,g,e,a,f,b){c.ktag||(a=function(){a.sendEvent?a.sendEvent(arguments):a.ktq.push(arguments)},a.ktq=[],c.ktag=a,f=d.getElementsByTagName(e)[0],b=d.createElement(e),b.async=!0,b.src=g,f.parentNode.appendChild(b))}(window,document,"//resources.xg4ken.com/js/v2/ktag.js?tid\x3dKT-N3B0B-3EB","script");ktag("setup","KT-N3B0B-3EB","\x3cUSER_ID\x3e");</script>
# <noscript>
# 	<img src="https://events.xg4ken.com/pixel/v2?tid=KT-N3B0B-3EB&amp;noscript=1" width="1" height="1" style="display:none">
# </noscript>
# <script type="text/javascript" id="">(function(){var a=window.location.href,b="//ads.pubmatic.com/AdServer/js/pwt/159133/2355",c="";if(0<a.indexOf("pwtv\x3d")){var d=/pwtv=(.*?)(&|$)/g;a=d.exec(a);2<=a.length&&0<a[1].length&&(c="/"+a[1])}a=document.createElement("script");a.async=!0;a.type="text/javascript";a.src=b+c+"/pwt.js";b=document.getElementsByTagName("script")[0];b.parentNode.insertBefore(a,b)})();</script>
# <script type="text/javascript" id="" src="//js-sec.indexww.com/ht/p/192296-54369691430157.js"></script><script type="text/javascript" id="">(function(f,c,d,e,a,b){a=c.createElement(d);a.async=1;a.src=e;b=c.getElementsByTagName(d)[0];b.parentNode.insertBefore(a,b)})(window,document,"script","https://adc-js.nine.com.au/adc.js");</script><script type="text/javascript" id="" src="//z.moatads.com/domainauheader364853395177/moatheader.js"></script><script type="text/javascript" id="">"undefined"!==typeof nSdkInstance&&(nSdkInstance.ggPM("staticend",staticMetadataObject),sdkNseNo=++sdkNseNo,staticMetadataObject.referrerURL=staticMetadataObject.pageURL||window.location,staticMetadataObject.pageURL="page_"+sdkNseNo+"_"+window.location,staticMetadataObject.assetid=window.location.href,nSdkInstance.ggPM("staticstart",staticMetadataObject));</script>
# <script type="text/javascript" id="" src="https://domain-static.s3-ap-southeast-2.amazonaws.com/content/fe-static/%40domain-group/fe-outdated-browser/outdated-browser-85195b0c1b1611b8e4eb.prod.js"></script><script type="text/javascript" id="">var tag=document.querySelector('footer [href\x3d"https://advertisers.com.au/domain"]');tag&&tag.parentNode.removeChild(tag);</script><script async="" defer="" src="https://accounts.google.com/gsi/client" id="__GA_EXP__"></script><div style="width:0px; height:0px; display:none; visibility:hidden;" id="batBeacon649866099747"><img style="width:0px; height:0px; display:none; visibility:hidden;" id="batBeacon575645015592" width="0" height="0" alt="" src="https://bat.bing.com/action/0?ti=4073566&amp;tm=gtm001&amp;Ver=2&amp;mid=a1d5449a-87c8-494b-9283-7dcb61c5c7b6&amp;sid=f801d250baa411eb91a791041387ef0b&amp;vid=f801fc20baa411eb88ce9b57e7055b46&amp;vids=1&amp;pi=1200101525&amp;lg=en-US&amp;sw=2195&amp;sh=1235&amp;sc=24&amp;tl=57%20Curtin%20Ave,%20Abbotsford%20NSW%202046%20%7C%20Domain&amp;p=https%3A%2F%2Fwww.domain.com.au%2F57-curtin-ave-abbotsford-nsw-2046-2016992421&amp;r=&amp;lt=1507&amp;evt=pageLoad&amp;msclkid=N&amp;sv=1&amp;rn=651633"></div>
# <script type="text/javascript" id="">var pvar={cid:"f2",content:"domain",server:"secure-gl",cookies_enabled:!1};if("undefined"!=typeof nol_t)var trac=nol_t(pvar);"undefined"!=typeof trac&&trac.record().post();</script>
# <noscript><div>
# <img src="//secure-au.imrworldwide.com/cgi-bin/m?ci=f2&amp;cg=domain&amp;cc=0&amp;ts=noscript" width="1" height="1" alt="">
# </div></noscript>
# <iframe name="_hjRemoteVarsFrame" title="_hjRemoteVarsFrame" id="_hjRemoteVarsFrame" src="https://vars.hotjar.com/box-21ccaa45726c0f3c8c458f7a87eb2298.html" style="display: none !important; width: 1px !important; height: 1px !important; opacity: 0 !important; pointer-events: none !important;"></iframe>
# <script type="text/javascript" id="">var sdkNseNo=0,_nolggGlobalParams={sfcode:"dcr",apid:"PF5073599-31A3-4F8A-98F7-B83D5B444D71",apn:"Domain",nsdkv:"511"},staticMetadataObject={type:"static",dataSrc:"cms",assetid:"https:\/\/www.domain.com.au\/57-curtin-ave-abbotsford-nsw-2046-2016992421",section:"Domain - brand only",segB:"DR Combined"},nSdkInstance=NOLCMB.getInstance(_nolggGlobalParams.apid);nSdkInstance.ggInitialize(_nolggGlobalParams);nSdkInstance.ggPM("staticstart",staticMetadataObject);</script><script type="text/javascript" id="">"function"!==typeof window.DIL&&(window.DIL=function(a,b){var f=[],d;a!==Object(a)&&(a={});var h=a.partner;var e=a.containerNSID;var k=!!a.disableDestinationPublishingIframe;var m=a.iframeAkamaiHTTPS;var v=a.mappings;var n=a.uuidCookie;var r=!0===a.enableErrorReporting;var C=a.visitorService;var y=a.declaredId;var O=!0===a.removeFinishedScriptsAndCallbacks;var P=!0===a.delayAllUntilWindowLoad;var H=!0===a.disableIDSyncs;var D=!0===a.disableScriptAttachment;var Q=!0===a.disableCORSFiring;var R=!0===
# a.disableDefaultRequest;var L=a.afterResultForDefaultRequest;var I=a.dpIframeSrc;var S=!0===a.testCORS;var T=!0===a.useJSONPOnly;var U=a.visitorConstructor;r&&DIL.errorModule.activate();var V=!0===window._dil_unit_tests;(d=b)&&f.push(d+"");if(!h||"string"!==typeof h)return d="DIL partner is invalid or not specified in initConfig",DIL.errorModule.handleError({name:"error",message:d,filename:"dil.js"}),Error(d);d="DIL containerNSID is invalid or not specified in initConfig, setting to default of 0";
# ...
# "style"),d=p("tt-wrap"),g=p("tt-close"),h=p("tt-warn","pre"),k=p("tt-display","pre"),l="#tt-wrap{position:absolute;top:0;left:0;width:100%;z-index:1000000000;background-color:#DDD;min-height:30px}@media (min-width:992px){#tt-wrap{left:25%;width:50%;overflow:hidden;border:1px #999 solid}}#tt-wrap pre{font:12pt monospace;color:#000;overflow:auto;white-space:pre;word-wrap:normal;margin:0;padding:5px}#tt-warn{display:none}.good #tt-warn{display:block;background-color:#090;color:#FFF}.warn #tt-warn{display:block;background-color:#990;color:#FFF}.err #tt-warn{display:block;background-color:#900;color:#FFF}#tt-close{position:absolute;width:30px;height:30px;right:0;top:0;background-image:url(http://ads.fairfax.com.au/TechOps/images/CloseBtn.png);background-size:30px 60px}\n",
# m=!1;d.className=a?a:"";h.innerHTML=b;k.innerHTML=c;e.type="text/css";e.id="tt-styles";e.styleSheet?e.styleSheet.cssText=l:e.innerHTML=l;d.id||(d.id="tt-wrap",g.id="tt-close",g.onclick=f,g.ontouchend=f,h.id="tt-warn",k.id="tt-display",d.appendChild(g),d.appendChild(h),d.appendChild(k),n.body.appendChild(e),n.body.appendChild(d))}function w(){u=m.digitalData||{};N=u.page||{};A=N.pageInfo||{};k=u.titan||{};l=k.adKeyValues||{};x=A.sysEnv;y=k.adSite;t=k.adZone;z=l.ctype;E=k.adSlots||[];F=k.adSlotsAdditional||
# [];B=E.concat(F)}function G(c){"true"==h.titanDebug&&"true"==h.titanRegistry||(h.titanDebug="true",h.titanRegistry="true",h.titanClear="true",titan.rebuild());c()}function K(){for(var c,a,b=titan.logHolder||[],f=0,e="",d="good",g="Ok";f<b.length;f++)c=b[f],a=c.match(/^e:/),e&&(e+="\n"),e+=a?'\x3cspan style\x3d"color:#F00;"\x3e'+c.substr(2)+"\x3c/span\x3e":c,a&&(g="Errors Logged",d="err");q(e,d,g);titan.consoleState&&(titan.consoleState.name="log")}function I(){w();var c,a=n.querySelectorAll("div[id^\x3dadspot]"),
# b={},f="",e="err",d="DataLayer Discrepancies Found";for(c=a.length-1;0<=c;c--){var g=a[c];g.innerHTML.match(/onditional ?(Ad|Titan)/)||(b[g.id]="On page, not in DataLayer")}for(c=B.length-1;0<=c;c--)g=B[c],b[g]?b[g].match(/^In DataLayer/)?b[g]="Duplicate in DataLayer, not on page":b[g].match(/Both/)?b[g]="Duplicate value in DataLayer":b[g].match(/On page/)&&(b[g]="Both"):b[g]="In DataLayer, not on page";g=b["adspot-interstitial"];b["adspot-interstitial"]=g&&!g.match(/not on page/)?"Both":"Interstitial slot missing from page";
# for(g in b)b.hasOwnProperty(g)&&"Both"!==b[g]&&(f+=g+": "+b[g]+"\n",e="err");""===f&&(f="No DataLayer/page discrepancies",e="good",d="Ok");f=f.replace(/\n$/,"");q(f,e,d)}function H(){w();var c="mobile"==x,a="",b,f=0,e="err";if(C(u))a+="DataLayer is not defined\n";else if(C(k))a+="Titan section is not defined\n";else if(y||(a+="adSite is not defined\n"),t?t.match(/\/$/)&&(a+='adZone cannot end in "/"\n'):a+="adZone is not defined\n",C(l)&&(a+="adKeyValues are not defined\n"),z||(a+="ctype is not defined\n"),
# l.cat||(a+="cat is not defined\n"),0===B.length)a+="adSlots are missing";else for(b=E.concat(F);f<b.length;f++)b[f].match(/^adspot-((\d+x\d+_?)+-pos-?\d$|int)/)||(a+="Invalid adslot format: "+b[f]+"\n");a||(e="good",a="Ok");Array.prototype&&delete Array.prototype.toJSON;q(JSON.stringify(u,null,c?1:4),e,a)}function L(){var c;var a=titan.displayedSlots;var b="",f="warn",e="No ads on this page";for(c in a){f="good";e="Unique Ad IDs";b+="\x3cb\x3e"+c+"\x3c/b\x3e\n";var d=c;a=d.match(/(?:\d+x\d+_?|int)+/i);
# d=d.match(/pos-?(\d+)/i);var g=[];a=(w(),g.push(k.adSite,l.ctype,l.cat,l.cat1,d?d[1]:null,a?a[0]:null,A.sysEnv),g.join("|"));b+="ID: "+a+"\n";b+="Hash: "+D(a)+"\n"}q(b,f,e);titan.consoleState&&(titan.consoleState.name="uniqueRef")}var u,N,A,k,l,x,y,t,z,E,F,B,r=m.location,v=r.search,h=m.localStorage;m.titan=m.titan||{};titan.toolsInitialised?O("Attempt to load titan tools failed as it has already initialised"):(titan.toolsInitialised=!0,P(),v.match(/datalayervalidate=true/i)?H():v.match(/checkadspots=true/i)?
# I():v.match(/displaylogs=true/i)?G(K):v.match(/getaddetails=true/i)?G(M):v.match(/showuniqueref=true/i)?G(L):"true"==h.titanClear&&(h.removeItem("titanDebug"),h.removeItem("titanRegistry"),h.removeItem("titanClear")),setTimeout(Q,3E3))}(window,document);</script><script type="text/javascript" id="">(function(){function d(){b&&e.forEach(function(a){a.isPublished||(a.target.postMessage(b,"*"),a.isPublished=!0)})}function f(a){"getDynData"===a.data&&e.push({isPublished:!1,target:a.source});d()}function g(a){if("undefined"!==typeof digitalData&&digitalData.page&&digitalData.page.pageInfo&&digitalData.page.pageInfo.property){a=JSON.parse(JSON.stringify(digitalData.page.pageInfo.property));a["x-message"]="domain-propertyinfo";a.images=[];var c=null;Array.prototype.forEach.call(document.getElementsByTagName("meta"),
# function(a){"og:image"===a.getAttribute("property")&&(c=a.getAttribute("content"))});c&&a.images.push(c);b=a;d()}}var b=null,e=[];window.addEventListener?addEventListener("message",f,!1):attachEvent("onmessage",f);"complete"===document.readyState||"loaded"===document.readyState||"interactive"===document.readyState?g():document.addEventListener&&document.addEventListener("DOMContentLoaded",g)})();</script><script type="text/javascript" id="">/*
#  Titan (Source - v2.1.3) - Begin  Titan (Source - v2.1.3) - End */
# function runTitan(){!function(l,g){function y(a){return"[object Array]"===Object.prototype.toString.call(a)}function Z(a){for(var b in a)if(a.hasOwnProperty(b))return!1;return!0}function I(a){var b=a[0];return y(b)?b:Array.prototype.slice.call(a)}function Da(a){for(var b,c=[];a.length;)b=a.shift(),y(b)?c=c.concat(b):c.push(b);return c}function aa(a){return(typeof a).match(/number|boolean/)?a.toString():a}function h(a){r&&"true"==r.titanLog&&console.log("TITAN: "+a);J.push(a);C()}function K(a){r&&
# "true"==r.titanLog&&console.error("TITAN: "+a);J.push("e:"+a);C()}function Ea(){titan.spa=Fa;titan.showAds=D;titan.refreshAds=ba;titan.clearAds=ca;titan.pageActive=Ga;titan.adReturnedEvent=Ha;titan.updateValues=z;E&&(titan.extensionCallback=da);ea();titan.rebuild=function(){ea()};titan.version="v2.1.1"}function ea(){r&&"true"==r.titanRegistry&&(titan.getReturnedAds=Ia);r&&"true"==r.titanDebug&&(titan.adSlotRegistry=n,titan.displayedSlots=L,titan.logHolder=J);titan.toolsRebuild&&titan.toolsRebuild()}
# function M(a){var b=g.cookie.match(new RegExp(a+"\x3d([^;]*)"));var c=0;if(b){for(b=b[1].split("%3B");c<b.length;c++){var d=b[c].replace(/%20/,"-").split("%3D");var e=1<d.length?d[1]:d[0];p["aam_did"==a?"u":1<d.length?d[0]:a]=e.match(/%2C/)?e.split("%2C"):e}m.adKeyValues=p}}function Ja(a){N||fa();var b=a.slot.getSlotId().getDomId();t[b]={isEmpty:a.isEmpty,lineItem:a.lineItemId,creative:a.creativeId,size:a.size};ha([b],a.isEmpty);h(a.isEmpty?"slotRendered but no ad to return - "+b:"slotRendered - "+
# b);O[b]&&O[b]({adId:b,adReturned:!a.isEmpty,size:a.size});C()}function Ka(){l.addEventListener&&l.addEventListener("message",function(a){"ffxhandshake"===a.data&&(h("Handshake received, posting response"),a.source.postMessage("ffxconfirmed","*"))})}function Ga(){A?ba():D()}function Ha(a,b){("string"==typeof a||"function"==typeof b)&&(O[a]=b,t[a]&&b({adId:a,adReturned:!t[a].isEmpty,size:t[a].size}))}function ia(a,b){l.addEventListener?l.addEventListener(a,b):l.attachEvent&&l.attachEvent("on"+a,b)}
# function C(){titan.consoleState&&"adDetails"==titan.consoleState.name&&titan.getAdDetails();titan.consoleState&&"log"==titan.consoleState.name&&titan.displayLogs();titan.consoleState&&"uniqueRef"==titan.consoleState.name&&titan.showUniqueRef()}function La(){(E=m.extensionEnabled)&&(P||h("Pausing for extensions"),Q=!1,R(),setTimeout(function(){da(!0)},3E3))}function da(a){P||A?A&&E&&h("Extension Callback Time Exceded"):(h("Extension Callback "+(a?"Timeout":"Run")),D());E=!1}function z(){v=l.digitalData||
# {};ja=v.page||{};q=ja.pageInfo||{};m=v.titan||{};u=m.adTester||{};p=m.adKeyValues||{};B=m.adSite;S=m.adZone;F=m.spa||1>ka().length;v.titan=m;l.digitalData=v;M("sav");M("csub");M("aam_did");var a=/adcall[^=]{0,3}=[^&]*/gi;var b=la?la.adtester:null;var c=ma.search.match(a)||(b?b.match(a):null);if(c){for(b=c.length-1;0<=b;b--)a=c[b].split("\x3d"),u[a[0]]=a[1].split("_");m.adTester=u}T=y(u.adcall)&&y(u.adcallkw)}function Ma(){var a=!0,b=B&&B.match(/smh|age/i)&&"article"==p.ctype&&g.cookie.match(/tsub=[^;]*/i);
# Z(v)&&(a=!1);Z(m)&&(a=!1);B||(a=!1);S||(a=!1);a||K("Minimum dataLayer requirements not met");(b||m.delay)&&(a=!1,P=!0,h(b?"Pausing for subscriptions":"Pausing for pageActive or showAds call"),R());Q=a}function D(){A||(A=!0,h("Titan Activation"),googletag.cmd.push(function(){z();var a=v.user||{};a=a.profile||{};a=a.fid||p.u||a.vendorID;F?(h("In SPA mode"),googletag.pubads().disableInitialLoad(),na(),titan.cmd.push(fa)):oa();googletag.pubads().setCentering(!0);googletag.pubads().enableSingleRequest();
# googletag.pubads().enableAsyncRendering();googletag.pubads().addEventListener("slotRenderEnded",Ja);a&&googletag.pubads().setPublisherProvidedId(a);googletag.enableServices();h("Google Service Enabled");R();Na()}))}function U(){for(var a in w){var b;if(b=w.hasOwnProperty(a)&&w[a]){b=a;var c=g.documentElement,d=l.innerHeight||c.clientHeight;c=l.pageYOffset||c.scrollTop;var e=g.getElementById(b),f=(e=e&&e.parentNode.className.match(/adWrapper/i)&&e.parentNode)&&e.offsetTop;e=!1;b=(f?c+d>=f&&f>=c&&(e=
# !0):(K("Cannot determine ad position ("+b+")"),e=!0),e)}b&&(h("Lazy Load Ad Viewable - "+a),w[a]=!1,titan.requestConditionalAd.push(a))}}function G(a,b){var c=[].concat.apply(Da(a),I(b));return c}function R(){pa||(pa=!0,h("Command Enabled"),titan.cmd.push=function(){for(var a=G(titan.cmd,arguments);a.length;)googletag.cmd.push(a.shift())},titan.cmd.push())}function Na(){titan.requestAd.push=function(){for(var a,b=G(titan.requestAd,arguments);b.length;)a=b.shift(),"string"==typeof a&&!L[a]&&(h("RequestAd - "+
# a),L[a]=!0,googletag.display(a))};titan.requestAd.push()}function fa(){N||(N=!0,h("Setting up Conditional Ad Requests"),titan.requestConditionalAd.push=function(){var a=G(titan.requestConditionalAd,arguments),b=a.slice(),c=[];for(V();a.length;){var d=qa(a.shift());var e=d.getSlotId().getDomId();h("RequestConditionalAd - "+e);d&&(d.setTargeting("condAd","true"),w.hasOwnProperty(e)&&d.setTargeting("lazyAd","true"),c.push(d))}!F&&c.length&&H(c);titan.requestAd.push(b);F&&c.length&&H(c)},titan.requestConditionalAd.push(),
# Oa())}function Oa(){h("Setting up Lazy Load Ad Requests");titan.requestLazyAd.push=function(){for(var a,b=G(titan.requestLazyAd,arguments);b.length;)h("Request Lazy Load - "+(a=b.shift())),w[a]=!0,ra||(ra=!0,ia("scroll",U),ia("resize",U));U()};titan.requestLazyAd.push()}function sa(){var a="div[id^\x3dadops],#theBgDiv,#gutterDiv";for(var b=g.querySelectorAll("style[id^\x3dadops]"),c=g.querySelectorAll("div[class*\x3dadops]"),d=g.body;g.querySelector(a);){var e=g.querySelector(a);e.innerHTML="";e.parentNode.removeChild(e)}for(a=
# b.length-1;0<=a;a--)e=b[a],e.parentNode.removeChild(e);for(a=c.length-1;0<=a;a--)e=c[a],e.className=e.className.replace(/\s?(adops-[^\s]*)/g,"");d.className=d.className.replace(/\s?(hasGutter-full|hasGutter-hide|adops-[^\s]*)/g,"")}function ba(){var a=ta(ua(arguments));a&&(sa(),V(),H(a))}function Ia(){return t}function ha(a,b){for(var c,d,e=0;e<a.length;e++){if((c=(adDiv=g.getElementById(a[e]))&&adDiv.parentNode)&&c.className.match(/adwrapper/i)){d=c.getElementsByTagName("small")[0];var f=/\sad(?=\s|$)/g,
# k=c.className;b?c.className=k.replace(f,""):k.match(f)||(c.className+=" ad")}d&&(d.style.display=b?"none":"")}}function Pa(a){for(var b=a.toLowerCase().match(/\d+x\d+/g),c=[];b.length;)a=b.shift().split("x"),c.push([Number(a[0]),Number(a[1])]);return c}function ua(a){var b;a=I(a);if(!a.length)for(b in n)n.hasOwnProperty(b)&&a.push(b);return a}function ta(){for(var a,b=I(arguments),c=0,d=[];c<b.length;c++)a=b[c],(a=a.getName?a:n[a])&&d.push(a);return d.length?d:null}function ka(){var a=m.adSlots||
# [],b=m.adSlotsAdditional||[];a=T?a.concat(b):a.slice();b=[];var c=[],d=a.length-1;for(a.sort();0<=d;d--)a[d].match(/300x250.*-pos-?1/i)?b.unshift(a.splice(d,1)[0]):a[d].match(/728x90.*-pos-?1/i)?b.push(a.splice(d,1)[0]):a[d].match(/pos-?1/i)||c.push(a.splice(d,1)[0]);return b.concat(a,c)}function oa(){z();var a,b=ka(),c=0;var d=m.supInt;var e={},f=[];for(d||b.push("adspot-interstitial");c<b.length;c++)d=b[c],d.match(/[^-]*-(((\d+x\d+_?)|fluid)*-pos-?\d|int)/i)&&!e[d]&&(e[d]=!0,a=qa(d),a&&f.push(a));
# return na(),f}function na(){var a,b={},c=m.adExclusions;for(a in p)p.hasOwnProperty(a)&&(b[a]=p[a]);q.pageID&&(b.pageID=q.pageID);q.sysEnv&&(b.sysEnv=q.sysEnv);q.layout&&(b.layout=q.layout);for(q.generator&&(b.generator=q.generator);W.length;)googletag.pubads().clearTargeting(W.shift());if(va(b),V(),googletag.pubads().clearCategoryExclusions(),c&&y(c))for(a=c.length-1;0<=a;a--)googletag.pubads().setCategoryExclusion(c[a]);else c&&"string"==typeof c&&googletag.pubads().setCategoryExclusion(c)}function va(a){if("[object Object]"===
# Object.prototype.toString.call(a))for(var b in a)a.hasOwnProperty(b)&&void 0!==a[b]&&(b.match(/br(v|m)s/)||W.push(b),googletag.pubads().setTargeting(b,aa(a[b])))}function qa(a){var b;var c=a;var d,e=u.adcallsz;var f=u.adcallpos;var k=!0;if(T||(k=!1),k&&e)for(k=!1,d=e.length-1;0<=d;d--)c.match(e[d])&&(k=!0);if(k&&f&&!c.match(/int/))for(k=!1,d=f.length-1;0<=d;d--)c.match(new RegExp("pos-?"+f[d]))&&(k=!0);c=k;f="/31694718/"+(c?"onl.adtester":B+"/"+S);k=a.match(/int/);var g=a.match(/fluid/);d={};var h=
# a.match(/pos-?(\d+)/i);e=navigator.userAgent.match(/MSIE\s[5-9]\./i);if(n[a])return n[a];k?n[a]=googletag.defineOutOfPageSlot(f,a):g?(n[a]=googletag.defineSlot(f,"fluid",a),d.pos=h?h[1]:"0"):(n[a]=googletag.defineSlot(f,Pa(a),a),d.pos=h?h[1]:"0");k=a;f=k.match(/(?:\d+x\d+_?|int|fluid)+/i);k=k.match(/pos-?(\d+)/i);g=[];f=(z(),g.push(m.adSite,p.ctype,p.cat,p.cat1,k?k[1]:null,f?f[0]:null,q.sysEnv),g.join("|"));e||(d.ur=f);e=f;f=0;if(0!==e.length)for(k=0;k<e.length;k++)g=e.charCodeAt(k),f=(f<<5)-f+g,
# f&=f;e=f;d.urh=e;n[a].addService(googletag.pubads()).setCollapseEmptyDiv(!0,!0);c&&(d.adcallkw=u.adcallkw);for(b in d)d.hasOwnProperty(b)&&n[a].setTargeting(b,aa(d[b]));return X&&titan.requestAd.push(a),n[a]}function ca(){var a=ua(arguments),b=ta(a);if(b){var c=a,d;if(c.length)for(d=c.length-1;0<=d;d--)delete t[c[d]];else for(d in t)delete t[d];googletag.pubads().clear(b);ha(a,!0);h("Clear Adslots - "+(a.length?a.join(", "):"All"));sa();C()}}function Fa(){h("Running Spa");X=!0;wa&&ca(Y);wa=!0;Y=oa();
# X=!1;H(Y)}function H(a){googletag.pubads().refresh(a)}function Qa(){var a;(x="hidden")in g?a="visibilitychange":(x="mozHidden")in g?a="mozvisibilitychange":(x="webkitHidden")in g?a="webkitvisibilitychange":(x="msHidden")in g&&(a="msvisibilitychange");a&&g.addEventListener(a,xa);ya=x in g;xa()}function xa(){za=g[x]?!1:!0}function V(){va({brms:ya,brvs:za})}var v,ja,q,m,u,p,B,S,T,A,pa,Q,x,ya,za,ra,F,wa,X,Y,N,P,E,ma=l.location,Aa=ma.protocol,Ba=g.getElementsByTagName("script")[0],Ca=g.createElement("script"),
# r=l.localStorage,la=l.sessionStorage,J=[],W=[],n={},L={},t={},O={},w={};l.googletag=l.googletag||{};googletag.cmd=googletag.cmd||[];l.titan=l.titan||{};titan.cmd=titan.cmd||[];titan.requestAd=titan.requestAd||[];titan.requestConditionalAd=titan.requestConditionalAd||[];titan.requestLazyAd=titan.requestLazyAd||[];z();titan.initialised?K("Attempt to load titan faild as titan has already initialised"):(titan.initialised=!0,Qa(),Ka(),Ma(),La(),Ca.src=("https:"==Aa?Aa:"http:")+"//www.googletagservices.com/tag/js/gpt.js",
# Ba.parentNode.insertBefore(Ca,Ba),Ea(),Q&&D())}(window,document)}setTimeout(function(){runTitan()},1E3);</script></body></html>

# %%
html
# Out:
# '<html lang="en-AU" data-version="8.15.239" data-build-git-hash="a926c9564214b38755c8b0ae458366efcd6a3bfb" data-build-time="Fri May 21 2021 10:26:01 GMT+1000 (Australian Eastern Standard Time)" data-build-id="master-3493"><head><link rel="dns-prefetch" href="//ads.rubiconproject.com"><link rel="dns-prefetch" href="//fastlane.rubiconproject.com"><meta charset="utf-8"><meta http-equiv="content-language" content="en-au"><meta name="format-detection" content="telephone=no"><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta name="viewport" content="width=device-width, initial-scale=1"><link rel="dns-prefetch" href="//static.domain.com.au"><link rel="dns-prefetch" href="//rimh2.domainstatic.com.au"><meta name="apple-mobile-web-app-capable" content="yes"><meta name="theme-color" content="#0ea800"><link rel="apple-touch-icon-precomposed" href="https://static.domain.com.au/domain/54.png"><link rel="apple-touch-icon-precomposed" href="https://static.domain.com.au/domain/72.png"><link rel="apple-touch-icon-precomposed" href="https://static.domain.com.au/domain/114.png"><link rel="apple-touch-icon-precomposed" href="https://static.domain.com.au/domain/144.png"><link rel="shortcut icon" href="https://static.domain.com.au/domain/favicon.ico"><link rel="preload" href="https://static.domain.com.au/content/fe-static/@domain-group/fe-brary/static/fonts/bolton/F37Bolton-Regular.woff2" as="font" type="font/woff2" crossorigin="true"><link rel="preload" href="https://static.domain.com.au/content/fe-static/@domain-group/fe-brary/static/fonts/bolton/F37Bolton-Bold.woff2" as="font" type="font/woff2" crossorigin="true"><title>Sold 970 Drummond Street, Carlton North VIC 3054 on 15 May 2021 - 2016951081 | Domain</title><meta name="description" content="970 Drummond Street, Carlton North VIC 3054 a 2 bedroom, 1 bathroom house sold for $2,255,000 on 2021-04-21T12:54:33.173. View listing details #2016951081 on Domain"><link rel="manifest" href="/manifest.json"><meta name="theme-color" content="#0ea800"><link rel="canonical" href="https://www.domain.com.au/970-drummond-street-carlton-north-vic-3054-2016951081"><meta property="og:title" content="Sold 970 Drummond Street, Carlton North VIC 3054 on 15 May 2021 - 2016951081 | Domain"><meta property="og:description" content="970 Drummond Street, Carlton North VIC 3054 a 2 bedroom, 1 bathroom house sold for $2,255,000 on 2021-04-21T12:54:33.173. View listing details #2016951081 on Domain"><meta property="og:type" content="product"><meta property="og:site_name" content="Domain"><meta property="og:url" content="https://www.domain.com.au/970-drummond-street-carlton-north-vic-3054-2016951081"><meta property="og:image" content="https://bucket-api.domain.com.au/v1/bucket/image/2016951081_1_1_210421_025433-w1600-h1067"><meta property="fb:app_id" content="505328276158724"><meta property="al:ios:url" content="domain.com.au://propertyDetails/2016951081"><meta property="al:ios:app_store_id" content="319908646"><meta property="al:ios:app_name" content="Domain Real Estate and Property"><meta property="al:android:url" content="domain://listing/2016951081"><meta property="al:android:package" content="com.fairfax.domain"><meta property="al:android:app_name" content="Domain"><meta name="twitter:card" content="gallery"><meta name="twitter:site" content="@Domaincomau"><meta name="twitter:title" content="Sold 970 Drummond Street, Carlton North VIC 3054 on 15 May 2021 - 2016951081 | Domain"><meta name="twitter:description" content="970 Drummond Street, Carlton North VIC 3054 a 2 bedroom, 1 bathroom house sold for $2,255,000 on 2021-04-21T12:54:33.173. View listing details #2016951081 on Domain"><meta name="twitter:image0" content="https://bucket-api.domain.com.au/v1/bucket/image/2016951081_1_1_210421_025433-w1600-h1067"><meta name="twitter:image1" content="https://bucket-api.domain.com.au/v1/bucket/image/2016951081_2_1_210421_025433-w1600-h1067"><meta name="twitter:image2" content="https://bucket-api.domain.com.au/v1/bucket/im ...

# %%
# parse object with BeautifulSoup as bs
soup = bs(html, 'html.parser')
summary = soup.find("div", class_="css-fpm9y")

# %%
property_features = summary.find_all('span', class_='css-1rzse3v')

bedrooms = property_features[0].text.split(' ')[0]
bathrooms = property_features[1].text.split(' ')[0]
cars = property_features[2].text.split(' ')[0]
landsize = property_features[3].text.split(' ')[0][:-2]

address = summary.find('h1', class_='css-164r41r').text
property_type = summary.find('span', class_='css-in3yi3').text

print(landsize, bedrooms, bathrooms, cars, address, property_type)
# Out:
# 247 2 1 1 970 Drummond Street Carlton North VIC 3054 House

# %%
suburb = address.split(' ')[3]
suburb
# Out:
# 'Abbotsford'

# %%
postcode = address.split(' ')[-1]
postcode
# Out:
# '2046'

# %% [markdown]
# # SEARCHING AN ADDRESS ON REALESTATE.COM.AU

# %%
url1 = 'https://www.domain.com.au/42-avenue-athol-canterbury-vic-3126-2016908730'

# %%
browser = initialise_browser()

# retrieve page with the requests module and visit url
response = requests.get(url1)
browser.visit(url1)

# getting the html code of browser
html = browser.html
